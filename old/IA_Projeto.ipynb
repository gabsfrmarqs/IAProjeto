# %% [markdown]
# ## <font color="blue">Preparação e Pré-processamento de Dados para Análise Preditiva entre Jogos Indie e Multi-A</font>
#
# ### <font color="red"><i>Análise Exploratória</i></font>
# ##### <font color="black">Neste Notebook o grupo realiza as alterações necessárias no Dataset mantém apenas as informações úteis e retirando valores inválidos</font>
# #### <font color="black"> Atualizações:
# ##### 21/09/2024 - Henrique Magno dos Santos - Remover valores nulos [8]
# ##### 21/09/2024 - Henrique Magno dos Santos - Removeu valores nulos de avgPlaytime [48]
# ##### 21/09/2024 - Gabriel de França Marques - Removeu publisherClass Hobbyist por só ter uma entrada [32]
# ##### 21/09/2024 - Pedro Machado Gomes Caixeta - Removeu a coluna steamID por não ter relevância nos resultados [35]
# ##### 21/09/2024 - Gabriel de França Marques - Em One-Hot encoding utilizamos publisherClass
# ##### 28/09/2024 - Gabriel de França Marques - Removeu publisherClass AA e AAA por ter poucas entradas em comparação a Indie [32]
# ### <font color="black" size='3'><b>Grupo em ordem alfabética (máx. 3 alunos) </b></font>
# <html>
# <table border="1px">
# <tr>
# <td bgcolor="Aquamarine">Nome do Aluno</td>
# <td bgcolor="Aquamarine">RA</td>
# </tr>
# <tr>
# <td bgcolor="white">Gabriel de França Marques</td>
# <td bgcolor="white">10395270</td>
# </tr>
# <tr>
# <td bgcolor="white">Henrique Magno dos Santos</td>
# <td bgcolor="white">10335286</td>
# </tr>
#     <tr>
# <td bgcolor="white">Pedro Machado Gomes Caixeta</td>
# <td bgcolor="white">10314309</td>
# </tr>
#     </table>
# </html>

# %% [markdown]
# # Preparação dos dados

# %%
import sklearn as sl
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
sl.__version__
# Out:
# '1.5.2'

# %% [markdown]
# ## Revisando a Análise Exploratória dos Dados:
# ## Estatística Descritva

# %%
# Carregando arquivo csv usando Pandas (método que usaremos neste notebook)
# Leitura do arquivo CSV com separador "," e codificação UTF-8
dfsteam = pd.read_csv('Steam_2024_bestRevenue_1500.csv', sep = ',', encoding = 'UTF-8')

# %%
# Mostra os 5 primeiros registros (objetos)
dfsteam.head()
# Out:
#                               name releaseDate  copiesSold  price    revenue  \
# 0                         WWE 2K24  07-03-2024      165301  99.99  8055097.0
# 1            EARTH DEFENSE FORCE 6  25-07-2024      159806  59.99  7882151.0
# 2        Sins of a Solar Empire II  15-08-2024      214192  49.99  7815247.0
# 3                 Legend of Mortal  14-06-2024      440998  19.99  7756399.0
# 4  Shin Megami Tensei V: Vengeance  13-06-2024      141306  59.99  7629252.0
#
#    avgPlaytime  reviewScore publisherClass                   publishers  \
# 0    42.365140           71            AAA                           2K
# 1    29.651061           57          Indie                  D3PUBLISHER
# 2    12.452593           88          Indie       Stardock Entertainment
# 3    24.797817           76          Indie  Paras Games,Obb Studio Inc.
# 4    34.258496           96             AA                         SEGA
#
#                                           developers  steamId
# 0                                    Visual Concepts  2315690
# 1                                            SANDLOT  2291060
# 2  Ironclad Games Corporation,Stardock Entertainment  1575940
# 3                                    Obb Studio Inc.  1859910
# 4                                              ATLUS  1875830

# %%
# Apresenta os dados dos três objetos iniciais
dfsteam.head(3)
# Out:
#                         name releaseDate  copiesSold  price    revenue  \
# 0                   WWE 2K24  07-03-2024      165301  99.99  8055097.0
# 1      EARTH DEFENSE FORCE 6  25-07-2024      159806  59.99  7882151.0
# 2  Sins of a Solar Empire II  15-08-2024      214192  49.99  7815247.0
#
#    avgPlaytime  reviewScore publisherClass              publishers  \
# 0    42.365140           71            AAA                      2K
# 1    29.651061           57          Indie             D3PUBLISHER
# 2    12.452593           88          Indie  Stardock Entertainment
#
#                                           developers  steamId
# 0                                    Visual Concepts  2315690
# 1                                            SANDLOT  2291060
# 2  Ironclad Games Corporation,Stardock Entertainment  1575940

# %%
# apresenta os tipos de dados dos atriutos do dataset
dfsteam.dtypes
# Out:
# name               object
# releaseDate        object
# copiesSold          int64
# price             float64
# revenue           float64
# avgPlaytime       float64
# reviewScore         int64
# publisherClass     object
# publishers         object
# developers         object
# steamId             int64
# dtype: object

# %%
# Mostra a dimensão (total de registros)
dfsteam.shape
# Out:
# (1500, 11)

# %%
# Detecta registros (objetos) - Nulos (NaN)
# Observe que há objetos contendo o condomínio nulo. Neste caso, vamos removê-los.
dfsteam.isnull().sum()
# Out:
# name              0
# releaseDate       0
# copiesSold        0
# price             0
# revenue           0
# avgPlaytime       0
# reviewScore       0
# publisherClass    0
# publishers        1
# developers        2
# steamId           0
# dtype: int64

# %%
# Remove rows with null values in the DataFrame
dfsteam = dfsteam.dropna()

# Verifique se os registros nulos foram removidos
print(dfsteam.isnull().sum())
# Out:
# name              0
# releaseDate       0
# copiesSold        0
# price             0
# revenue           0
# avgPlaytime       0
# reviewScore       0
# publisherClass    0
# publishers        0
# developers        0
# steamId           0
# dtype: int64

# %%
# Verifica se há registros (objetos) duplicados
dfsteam.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Groupby por developers
dfsteam.groupby('developers').size()
# Out:
# developers
# 0 Deer Soft               1
# 1000 Orks                 1
# 101XP GAME STUDIOS        1
# 14 Hours Productions      1
# 18bitStudio               1
#                          ..
# 蒸汽满满工作室                   1
# 雪山雞白郎,SnowGBL             1
# 零创游戏(ZerocreationGame)    1
# 雷鸣工作室                     1
# 香港商河洛互動娛樂股份有限公司           1
# Length: 1405, dtype: int64

# %%
# Groupby pelo publishers
dfsteam.groupby('publishers').size()
# Out:
# publishers
# 0 Deer Soft Partnership                  1
# 072 Project                             14
# 101XP                                    1
# 11 bit studios                           3
# 14 Hours Productions,Astrolabe Games     1
#                                         ..
# 老乌贼工作室                                   1
# 致意                                       1
# 蒸汽满满工作室                                  1
# 零创游戏(ZerocreationGame),2P Games          1
# 雷鸣工作室                                    1
# Length: 1131, dtype: int64

# %%
# Groupby pelas copiesSold
dfsteam.groupby('copiesSold').size()
# Out:
# copiesSold
# 593         1
# 700         1
# 710         1
# 725         1
# 827         1
#            ..
# 9877443     1
# 11905198    1
# 15517278    1
# 16704850    1
# 30739148    1
# Length: 1457, dtype: int64

# %%
# Groupby por price
dfsteam.groupby('price').size()
# Out:
# price
# 0.00      85
# 1.99       5
# 2.00       1
# 2.99      18
# 3.49       1
# 3.50       1
# 3.99      21
# 4.99      60
# 5.49       1
# 5.99      27
# 6.50       1
# 6.99      61
# 7.00       1
# 7.99      50
# 8.99      30
# 9.25       1
# 9.79       1
# 9.90       1
# 9.99     134
# 10.99     25
# 11.99     50
# 12.00      1
# 12.45      1
# 12.49      2
# 12.99     56
# 13.99     17
# 14.99    153
# 15.99     26
# 16.99     20
# 17.76      1
# 17.90      1
# 17.99     33
# 18.35      1
# 18.99     12
# 19.99    230
# 20.00      2
# 20.99      1
# 21.99      3
# 22.99      5
# 23.99      2
# 24.99    116
# 25.00      1
# 25.50      1
# 26.99      1
# 27.99      2
# 29.99     91
# 32.00      1
# 32.99      1
# 33.32      1
# 34.99     26
# 35.01      1
# 39.99     48
# 44.99      5
# 49.99     23
# 54.99      3
# 59.99     23
# 69.99     10
# 99.99      1
# dtype: int64

# %%
# Groupby por revenue
dfsteam.groupby('revenue').size()
# Out:
# revenue
# 20674.0        1
# 20723.0        1
# 20922.0        1
# 20946.0        1
# 20955.0        1
#               ..
# 111478291.0    1
# 217017892.0    1
# 392328553.0    1
# 435635596.0    1
# 837793356.0    1
# Length: 1494, dtype: int64

# %%
# Groupby por avgPlayTime
dfsteam.groupby('avgPlaytime').size()
# Out:
# avgPlaytime
# 0.000000      1
# 0.549644      1
# 0.628550      1
# 0.633411      1
# 0.671745      1
#              ..
# 239.439797    1
# 256.335003    1
# 260.340509    1
# 271.614628    1
# 296.332852    1
# Length: 1497, dtype: int64

# %%
# Groupby por reviewScore
dfsteam.groupby('reviewScore').size()
# Out:
# reviewScore
# 0      99
# 11      1
# 15      1
# 24      3
# 25      1
#        ..
# 96     46
# 97     52
# 98     38
# 99     32
# 100    10
# Length: 72, dtype: int64

# %%
# Groupby por publisherClass
dfsteam.groupby('publisherClass').size()
# Out:
# publisherClass
# AA        146
# AAA        52
# Indie    1299
# dtype: int64

# %%
# Groupby por steamId
dfsteam.groupby('steamId').size()
# Out:
# steamId
# 24880      1
# 251570     1
# 269770     1
# 290100     1
# 315210     1
#           ..
# 3067200    1
# 3088410    1
# 3089130    1
# 3091390    1
# 3107330    1
# Length: 1497, dtype: int64

# %%
# Sumário estatístico
dfsteam.describe()
# Out:
#          copiesSold        price       revenue  avgPlaytime  reviewScore  \
# count  1.497000e+03  1497.000000  1.497000e+03  1497.000000  1497.000000
# mean   1.417444e+05    17.531263  2.637561e+06    12.580062    76.205745
# std    1.133877e+06    12.649514  2.783787e+07    21.559777    24.342595
# min    5.930000e+02     0.000000  2.067400e+04     0.000000     0.000000
# 25%    4.922000e+03     9.990000  4.551800e+04     3.571454    72.000000
# 50%    1.197200e+04    14.990000  1.099730e+05     6.763299    83.000000
# 75%    3.831300e+04    19.990000  4.571630e+05    13.108251    92.000000
# max    3.073915e+07    99.990000  8.377934e+08   296.332852   100.000000
#
#             steamId
# count  1.497000e+03
# mean   2.184222e+06
# std    6.060862e+05
# min    2.488000e+04
# 25%    1.793090e+06
# 50%    2.321880e+06
# 75%    2.693730e+06
# max    3.107330e+06

# %%
df_numeric = dfsteam.select_dtypes(include=[float, int])
correlation_matrix = df_numeric.corr(method='pearson')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Apresenta o mapa de calor em da correlação
import seaborn as sns
ax = sns.heatmap(df_numeric.corr(), vmin=-1, vmax=1, center=0, annot=True, cmap = "PiYG")
sns.set(rc={'figure.figsize':(5,5)})
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45, # rotaciona o eixo y 45o
    horizontalalignment='right' 
);

# %%
df_numeric = dfsteam.select_dtypes(include=[float, int])
skew_values = df_numeric.skew()
print(skew_values)
# Out:
# copiesSold     18.600942
# price           1.577119
# revenue        22.897228
# avgPlaytime     7.164740
# reviewScore    -2.049449
# steamId        -0.796613
# dtype: float64

# %%
# Histograma Univariado
dfsteam.hist(figsize=(15, 15)).all()

plt.show()

# %%
# Density Plot Univariado
dfsteam.plot(kind = 'density', subplots = True, layout = (5,5), sharex = False, figsize=(20,20))

plt.show()

# %%
# Box and Whisker Plots
dfsteam.plot(kind = 'box', subplots = True, layout = (4,4), sharex = False, sharey = False, figsize=(20,20))

plt.show()

# %%
# Pairplot
sns.pairplot(dfsteam)

# %%
# Apresenta o histograma com uma curva suave e a normal
from scipy import stats
sns.distplot(dfsteam.price, fit = stats.norm);

# %% [markdown]
# ## Preparação dos dados ou Pré-processamento dos dados

# %%
# Mostra o total de objetos resultantes
dfsteam.shape
# Out:
# (1497, 11)

# %%
# Mostra os 3 primeiros registros (objetos)
dfsteam.head(3)
# Out:
#                         name releaseDate  copiesSold  price    revenue  \
# 0                   WWE 2K24  07-03-2024      165301  99.99  8055097.0
# 1      EARTH DEFENSE FORCE 6  25-07-2024      159806  59.99  7882151.0
# 2  Sins of a Solar Empire II  15-08-2024      214192  49.99  7815247.0
#
#    avgPlaytime  reviewScore publisherClass              publishers  \
# 0    42.365140           71            AAA                      2K
# 1    29.651061           57          Indie             D3PUBLISHER
# 2    12.452593           88          Indie  Stardock Entertainment
#
#                                           developers  steamId
# 0                                    Visual Concepts  2315690
# 1                                            SANDLOT  2291060
# 2  Ironclad Games Corporation,Stardock Entertainment  1575940

# %%
# Fazendo agrupamento por publisherClass
dfsteam.groupby('publisherClass').size()
# Out:
# publisherClass
# AA        146
# AAA        52
# Indie    1299
# dtype: int64

# %%
# Como há poucos objetos do tipo Hobbyist, AA e AAA, vamos remover
dfsteam.drop(dfsteam[dfsteam.publisherClass == "Hobbyist"].index, inplace=True)
dfsteam.drop(dfsteam[dfsteam.publisherClass == "AA"].index, inplace=True)
dfsteam.drop(dfsteam[dfsteam.publisherClass == "AAA"].index, inplace=True)

# %%
# Fazendo agrupamento por tipo de imóvel
dfsteam.groupby('publisherClass').size()
# Out:
# publisherClass
# Indie    1299
# dtype: int64

# %%
# Mostra o total de objetos resultantes
dfsteam.shape
# Out:
# (1299, 11)

# %%
# Como steamID não será relevante na nossa analise vamos remove-lo
dfsteam = dfsteam.drop('steamId', axis=1)

# %%
# Mostra os 3 primeiros registros (objetos)
dfsteam.head(3)
# Out:
#                         name releaseDate  copiesSold  price    revenue  \
# 1      EARTH DEFENSE FORCE 6  25-07-2024      159806  59.99  7882151.0
# 2  Sins of a Solar Empire II  15-08-2024      214192  49.99  7815247.0
# 3           Legend of Mortal  14-06-2024      440998  19.99  7756399.0
#
#    avgPlaytime  reviewScore publisherClass                   publishers  \
# 1    29.651061           57          Indie                  D3PUBLISHER
# 2    12.452593           88          Indie       Stardock Entertainment
# 3    24.797817           76          Indie  Paras Games,Obb Studio Inc.
#
#                                           developers
# 1                                            SANDLOT
# 2  Ironclad Games Corporation,Stardock Entertainment
# 3                                    Obb Studio Inc.

# %% [markdown]
# ### Limpeza de Dados - Dados Incompletos

# %%
# Mostra os 5 primeiros registros (objetos)
dfsteam.head()
# Out:
#                         name releaseDate  copiesSold  price    revenue  \
# 1      EARTH DEFENSE FORCE 6  25-07-2024      159806  59.99  7882151.0
# 2  Sins of a Solar Empire II  15-08-2024      214192  49.99  7815247.0
# 3           Legend of Mortal  14-06-2024      440998  19.99  7756399.0
# 5                   Soulmask  30-05-2024      304685  29.99  7540563.0
# 6              The Universim  22-01-2024      328945  29.99  7534369.0
#
#    avgPlaytime  reviewScore publisherClass                   publishers  \
# 1    29.651061           57          Indie                  D3PUBLISHER
# 2    12.452593           88          Indie       Stardock Entertainment
# 3    24.797817           76          Indie  Paras Games,Obb Studio Inc.
# 5    95.697813           79          Indie                Qooland Games
# 6    16.868531           81          Indie                      Crytivo
#
#                                           developers
# 1                                            SANDLOT
# 2  Ironclad Games Corporation,Stardock Entertainment
# 3                                    Obb Studio Inc.
# 5                                    CampFire Studio
# 6                                            Crytivo

# %%
# Detecta o total de objetos ccontedo Nulos
dfsteam.isnull().sum()
# Out:
# name              0
# releaseDate       0
# copiesSold        0
# price             0
# revenue           0
# avgPlaytime       0
# reviewScore       0
# publisherClass    0
# publishers        0
# developers        0
# dtype: int64

# %%
# Remove os objetos com valores nulos
dfsteam.dropna(inplace=True)

# %%
# Atualiza os índices após a remoção, sem incluir os índices antigos
dfsteam.reset_index(drop=True)
# Out:
#                            name releaseDate  copiesSold  price    revenue  \
# 0         EARTH DEFENSE FORCE 6  25-07-2024      159806  59.99  7882151.0
# 1     Sins of a Solar Empire II  15-08-2024      214192  49.99  7815247.0
# 2              Legend of Mortal  14-06-2024      440998  19.99  7756399.0
# 3                      Soulmask  30-05-2024      304685  29.99  7540563.0
# 4                 The Universim  22-01-2024      328945  29.99  7534369.0
# ...                         ...         ...         ...    ...        ...
# 1294               Lust Goddess  21-02-2024      456707   0.00  9695496.0
# 1295              Pacific Drive  21-02-2024      401030  29.99  9517954.0
# 1296        Infection Free Zone  11-04-2024      452146  24.99  8739530.0
# 1297            Dark and Darker  07-06-2024     2640903   0.00  8706135.0
# 1298                     Peglin  27-08-2024      544144  19.99  8125042.0
#
#       avgPlaytime  reviewScore publisherClass                     publishers  \
# 0       29.651061           57          Indie                    D3PUBLISHER
# 1       12.452593           88          Indie         Stardock Entertainment
# 2       24.797817           76          Indie    Paras Games,Obb Studio Inc.
# 3       95.697813           79          Indie                  Qooland Games
# 4       16.868531           81          Indie                        Crytivo
# ...           ...          ...            ...                            ...
# 1294    33.544343           48          Indie                     BRAWEA LTD
# 1295    18.181118            0          Indie             Kepler Interactive
# 1296    14.494432           73          Indie                Games Operators
# 1297    31.974027           74          Indie                       IRONMACE
# 1298    30.160995           82          Indie  Red Nexus Games Inc.,IndieArk
#
#                                              developers
# 0                                               SANDLOT
# 1     Ironclad Games Corporation,Stardock Entertainment
# 2                                       Obb Studio Inc.
# 3                                       CampFire Studio
# 4                                               Crytivo
# ...                                                 ...
# 1294                                         BRAWEA LTD
# 1295                                   Ironwood Studios
# 1296                                        Jutsu Games
# 1297                                           IRONMACE
# 1298                               Red Nexus Games Inc.
#
# [1299 rows x 10 columns]

# %% [markdown]
# ### Limpeza de Dados - Dados Inconsistentes

# %%
# Mostra o formato do dataset
dfsteam.shape
# Out:
# (1299, 10)

# %%
dfsteam.dtypes
# Out:
# name               object
# releaseDate        object
# copiesSold          int64
# price             float64
# revenue           float64
# avgPlaytime       float64
# reviewScore         int64
# publisherClass     object
# publishers         object
# developers         object
# dtype: object

# %%
dfsteam.groupby('publishers').size()
# Out:
# publishers
# 0 Deer Soft Partnership                  1
# 072 Project                             14
# 101XP                                    1
# 14 Hours Productions,Astrolabe Games     1
# 1Thousand                                1
#                                         ..
# 老乌贼工作室                                   1
# 致意                                       1
# 蒸汽满满工作室                                  1
# 零创游戏(ZerocreationGame),2P Games          1
# 雷鸣工作室                                    1
# Length: 1064, dtype: int64

# %%
# Identifica o total de publishers diferentes
dfsteam.publishers.nunique()
# Out:
# 1064

# %%
# Mostra os 5 primeiros registros (objetos)
dfsteam.head(5)
# Out:
#                         name releaseDate  copiesSold  price    revenue  \
# 1      EARTH DEFENSE FORCE 6  25-07-2024      159806  59.99  7882151.0
# 2  Sins of a Solar Empire II  15-08-2024      214192  49.99  7815247.0
# 3           Legend of Mortal  14-06-2024      440998  19.99  7756399.0
# 5                   Soulmask  30-05-2024      304685  29.99  7540563.0
# 6              The Universim  22-01-2024      328945  29.99  7534369.0
#
#    avgPlaytime  reviewScore publisherClass                   publishers  \
# 1    29.651061           57          Indie                  D3PUBLISHER
# 2    12.452593           88          Indie       Stardock Entertainment
# 3    24.797817           76          Indie  Paras Games,Obb Studio Inc.
# 5    95.697813           79          Indie                Qooland Games
# 6    16.868531           81          Indie                      Crytivo
#
#                                           developers
# 1                                            SANDLOT
# 2  Ironclad Games Corporation,Stardock Entertainment
# 3                                    Obb Studio Inc.
# 5                                    CampFire Studio
# 6                                            Crytivo

# %%
# Mostra o formato do dataset
dfsteam.shape
# Out:
# (1299, 10)

# %%
# Alguns valores de avgPlaytime estão zero, então vamos remove-los
dfsteam[dfsteam['avgPlaytime'] == 0]
# Out:
# Empty DataFrame
# Columns: [name, releaseDate, copiesSold, price, revenue, avgPlaytime, reviewScore, publisherClass, publishers, developers]
# Index: []

# %%
# Obtém os registros onde avgPlaytime = 0
df_remove = dfsteam.loc[dfsteam['avgPlaytime'] == 0]

# %%
# Remove os objetos nos quais não há informação do avgPlaytime, ou seja, seu valor é = 0
dfsteam.drop(df_remove.index, inplace=True)

# %%
# Mostra o formato do dataset resultante
dfsteam.shape
# Out:
# (1299, 10)

# %% [markdown]
# ### Limpeza de Dados - Dados Redundantes - Atributos

# %%
# Apresenta o mapa de calor em da correlação (Observe os atributos copiesSold + revenue, alta correlação positiva)
import seaborn as sns
dfsteam_numeric = dfsteam.select_dtypes(include=[float, int])
ax = sns.heatmap(dfsteam_numeric.corr(), vmin=-1, vmax=1, center=0, annot=True, cmap = "PiYG")
sns.set(rc={'figure.figsize':(18,18)})
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45, # rotaciona o eixo y 45o
    horizontalalignment='right' 
);

# %% [markdown]
# ### Limpeza de Dados - Ruídos

# %%
dfsteam.plot(kind = 'box', subplots = True, layout = (4,4), sharex = False, sharey = False, figsize=(20,20))
plt.show()

# %%
# Ordenando os dados pela coluna price
dfsteam_salvo = dfsteam.sort_values(by=['price']); dfsteam_salvo
# Out:
#                                                    name releaseDate  \
# 1496                                    Dark and Darker  07-06-2024
# 1489                                       Lust Goddess  21-02-2024
# 1483                                      Summoners War  07-01-2024
# 1479                         Firestone: Online Idle RPG  01-04-2024
# 56                                Viking Rise: Valhalla  21-05-2024
# ...                                                 ...         ...
# 856   GOBLIN SLAYER -ANOTHER ADVENTURER- NIGHTMARE F...  28-02-2024
# 365                                   TOKYO PSYCHODEMIC  29-05-2024
# 579                                        TopSpin 2K25  25-04-2024
# 1304                                Train Capacity 300%  26-06-2024
# 1                                 EARTH DEFENSE FORCE 6  25-07-2024
#
#       copiesSold  price       revenue  avgPlaytime  reviewScore  \
# 1496     2640903   0.00  8.706135e+06    31.974027           74
# 1489      456707   0.00  9.695496e+06    33.544343           48
# 1483      540801   0.00  1.078734e+07   112.856340            0
# 1479      335093   0.00  1.568936e+07   296.332852           79
# 56         20537   0.00  2.595130e+05    36.620297           75
# ...          ...    ...           ...          ...          ...
# 856          700  54.99  3.463800e+04     8.288816           48
# 365         1813  54.99  8.953900e+04     5.858586           24
# 579        45454  59.99  2.299213e+06    17.322995           49
# 1304       10037  59.99  4.994360e+05     3.783498           76
# 1         159806  59.99  7.882151e+06    29.651061           57
#
#      publisherClass               publishers               developers
# 1496          Indie                 IRONMACE                 IRONMACE
# 1489          Indie               BRAWEA LTD               BRAWEA LTD
# 1483          Indie                   Com2uS                   Com2uS
# 1479          Indie          Holyday Studios          Holyday Studios
# 56            Indie  IGG SINGAPORE PTE. LTD.  IGG SINGAPORE PTE. LTD.
# ...             ...                      ...                      ...
# 856           Indie           Bushiroad Inc.  APOLLOSOFT Inc.,mebius.
# 365           Indie                  GRAVITY       GRAVITY GAME ARISE
# 579           Indie                 2K Games                Hangar 13
# 1304          Indie              072 Project                    ベルゼブブ
# 1             Indie              D3PUBLISHER                  SANDLOT
#
# [1299 rows x 10 columns]

# %%
# Reorganiza os índices
dfsteam_salvo.reset_index(drop=True, inplace=True); dfsteam_salvo.head(5)
# Out:
#                          name releaseDate  copiesSold  price       revenue  \
# 0             Dark and Darker  07-06-2024     2640903    0.0  8.706135e+06
# 1                Lust Goddess  21-02-2024      456707    0.0  9.695496e+06
# 2               Summoners War  07-01-2024      540801    0.0  1.078734e+07
# 3  Firestone: Online Idle RPG  01-04-2024      335093    0.0  1.568936e+07
# 4       Viking Rise: Valhalla  21-05-2024       20537    0.0  2.595130e+05
#
#    avgPlaytime  reviewScore publisherClass               publishers  \
# 0    31.974027           74          Indie                 IRONMACE
# 1    33.544343           48          Indie               BRAWEA LTD
# 2   112.856340            0          Indie                   Com2uS
# 3   296.332852           79          Indie          Holyday Studios
# 4    36.620297           75          Indie  IGG SINGAPORE PTE. LTD.
#
#                 developers
# 0                 IRONMACE
# 1               BRAWEA LTD
# 2                   Com2uS
# 3          Holyday Studios
# 4  IGG SINGAPORE PTE. LTD.

# %%
# Apresenta o histograma do atributo preço
# Pode-se observar a presença de valores outliers (extremos) com valores altos
dfsteam_salvo.price.hist()
# Out:
# <Axes: >

# %%
# Cria um Boxplot Simples
# Cria uma Figura de tamanho 9x6 cm
fig = plt.figure(1, figsize=(9, 6))

# Cria subplots
# Estes são os parâmetros da grade do subplot codificados como um único inteiro. 
# Por exemplo, "111" significa "grade 1x1, primeiro subplot".
ax = fig.add_subplot(111)

bp = ax.boxplot(dfsteam_salvo['price'])

# %%
# Filtra apenas colunas numéricas no DataFrame
dfsteam_salvo_numeric = dfsteam_salvo.select_dtypes(include=[float, int])
tamanho = len(dfsteam_salvo_numeric)
# Calcula o primeiro e o terceiro quartil apenas para colunas numéricas
primeiro_quartil = dfsteam_salvo_numeric.quantile(q=0.25, axis=0, interpolation='linear')
terceiro_quartil = dfsteam_salvo_numeric.quantile(q=0.75, axis=0, interpolation='linear')

# %%
# qtde de objetos do dataset
tamanho
# Out:
# 1299

# %%
# Primeiro quartil do preço
primeiro_quartil
# Out:
# copiesSold      4561.000000
# price              8.990000
# revenue        42216.500000
# avgPlaytime        3.294169
# reviewScore       73.000000
# Name: 0.25, dtype: float64

# %%
# valor do terceiro quartil
terceiro_quartil
# Out:
# copiesSold      29867.000000
# price              19.990000
# revenue        311387.500000
# avgPlaytime        12.167482
# reviewScore        92.000000
# Name: 0.75, dtype: float64

# %%
# Calcula o FIQ
FIQ = terceiro_quartil.price - primeiro_quartil.price; FIQ
# Out:
# np.float64(10.999999999999998)

# %%
# Agora vem uma das partes mais importantes, vamos usar a regra 1,5xFIQ.
# Considerando o atributo prelo, faremos: Q1 - 1,5⋅FIQ e Q3 + 1,5⋅FIQ.
menor = primeiro_quartil.price - (int(FIQ) * 1.5)
maior = (int(FIQ) * 1.5) + terceiro_quartil.price

# %%
# outliers baixos estão abaixo do valor "menor".
menor
# Out:
# np.float64(-6.01)

# %%
# outliers altos estão acima do valor "maior".
maior
# Out:
# np.float64(34.989999999999995)

# %%
# Os objetos cujo resultado da comparação do atributo preço e "False" será um outlier
dfsteam_salvo.price > menor
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 1294    True
# 1295    True
# 1296    True
# 1297    True
# 1298    True
# Name: price, Length: 1299, dtype: bool

# %%
# Então, qualquer valor abaixo é um outlier e será removido do dataset. 
dfsteam_salvo = dfsteam_salvo[(dfsteam_salvo.price > menor)]; dfsteam_salvo
# Out:
#                                                    name releaseDate  \
# 0                                       Dark and Darker  07-06-2024
# 1                                          Lust Goddess  21-02-2024
# 2                                         Summoners War  07-01-2024
# 3                            Firestone: Online Idle RPG  01-04-2024
# 4                                 Viking Rise: Valhalla  21-05-2024
# ...                                                 ...         ...
# 1294  GOBLIN SLAYER -ANOTHER ADVENTURER- NIGHTMARE F...  28-02-2024
# 1295                                  TOKYO PSYCHODEMIC  29-05-2024
# 1296                                       TopSpin 2K25  25-04-2024
# 1297                                Train Capacity 300%  26-06-2024
# 1298                              EARTH DEFENSE FORCE 6  25-07-2024
#
#       copiesSold  price       revenue  avgPlaytime  reviewScore  \
# 0        2640903   0.00  8.706135e+06    31.974027           74
# 1         456707   0.00  9.695496e+06    33.544343           48
# 2         540801   0.00  1.078734e+07   112.856340            0
# 3         335093   0.00  1.568936e+07   296.332852           79
# 4          20537   0.00  2.595130e+05    36.620297           75
# ...          ...    ...           ...          ...          ...
# 1294         700  54.99  3.463800e+04     8.288816           48
# 1295        1813  54.99  8.953900e+04     5.858586           24
# 1296       45454  59.99  2.299213e+06    17.322995           49
# 1297       10037  59.99  4.994360e+05     3.783498           76
# 1298      159806  59.99  7.882151e+06    29.651061           57
#
#      publisherClass               publishers               developers
# 0             Indie                 IRONMACE                 IRONMACE
# 1             Indie               BRAWEA LTD               BRAWEA LTD
# 2             Indie                   Com2uS                   Com2uS
# 3             Indie          Holyday Studios          Holyday Studios
# 4             Indie  IGG SINGAPORE PTE. LTD.  IGG SINGAPORE PTE. LTD.
# ...             ...                      ...                      ...
# 1294          Indie           Bushiroad Inc.  APOLLOSOFT Inc.,mebius.
# 1295          Indie                  GRAVITY       GRAVITY GAME ARISE
# 1296          Indie                 2K Games                Hangar 13
# 1297          Indie              072 Project                    ベルゼブブ
# 1298          Indie              D3PUBLISHER                  SANDLOT
#
# [1299 rows x 10 columns]

# %%
# Os objetos cujo resultado da comparação do atributo preço e "False" será um outlier
dfsteam_salvo.price < maior
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 1294    False
# 1295    False
# 1296    False
# 1297    False
# 1298    False
# Name: price, Length: 1299, dtype: bool

# %%
# Então, qualquer valor acima é um outlier e será removido.
dfsteam_salvo = dfsteam_salvo[(dfsteam_salvo.price < maior)]; dfsteam_salvo
# Out:
#                                          name releaseDate  copiesSold  price  \
# 0                             Dark and Darker  07-06-2024     2640903   0.00
# 1                                Lust Goddess  21-02-2024      456707   0.00
# 2                               Summoners War  07-01-2024      540801   0.00
# 3                  Firestone: Online Idle RPG  01-04-2024      335093   0.00
# 4                       Viking Rise: Valhalla  21-05-2024       20537   0.00
# ...                                       ...         ...         ...    ...
# 1232                              New Star GP  07-03-2024       16009  29.99
# 1233                              Galacticare  23-05-2024       12476  29.99
# 1234  Nancy Drew®: Mystery of the Seven Keys™  20-06-2024        7242  32.00
# 1235                         Le Mans Ultimate  20-02-2024      120703  32.99
# 1236                                  Bodycam  07-06-2024      632326  33.32
#
#            revenue  avgPlaytime  reviewScore publisherClass  \
# 0     8.706135e+06    31.974027           74          Indie
# 1     9.695496e+06    33.544343           48          Indie
# 2     1.078734e+07   112.856340            0          Indie
# 3     1.568936e+07   296.332852           79          Indie
# 4     2.595130e+05    36.620297           75          Indie
# ...            ...          ...          ...            ...
# 1232  2.867360e+05     8.869371            0          Indie
# 1233  3.087590e+05    13.665298           91          Indie
# 1234  2.085690e+05     7.070747           60          Indie
# 1235  3.740762e+06    24.519898           78          Indie
# 1236  1.773208e+07     8.028880           74          Indie
#
#                      publishers               developers
# 0                      IRONMACE                 IRONMACE
# 1                    BRAWEA LTD               BRAWEA LTD
# 2                        Com2uS                   Com2uS
# 3               Holyday Studios          Holyday Studios
# 4       IGG SINGAPORE PTE. LTD.  IGG SINGAPORE PTE. LTD.
# ...                         ...                      ...
# 1232  Five Aces Publishing Ltd.      New Star Games Ltd.
# 1233                 CULT Games         Brightrock Games
# 1234            HeR Interactive          HeR Interactive
# 1235                 Studio 397               Studio 397
# 1236             Reissad Studio           Reissad Studio
#
# [1237 rows x 10 columns]

# %%
# mostra o shape (total de registros por colunas)
dfsteam_salvo.shape
# Out:
# (1237, 10)

# %%
# Cria um Boxplot Simples
# Cria uma Figura de tamanho 9x6 cm
fig = plt.figure(1, figsize=(9, 6))

# Cria subplots
# Estes são os parâmetros da grade do subplot codificados como um único inteiro. 
# Por exemplo, "111" significa "grade 1x1, primeiro subplot".
ax = fig.add_subplot(111)

bp = ax.boxplot(dfsteam_salvo['price'])

# %%
# apresenta o mapa de calor resultante
dfsteam_salvo_numeric = dfsteam_salvo.select_dtypes(include=[float, int])
ax = sns.heatmap(dfsteam_salvo_numeric.corr(), vmin=-1, vmax=1, center=0, annot=True, cmap = "PiYG")
sns.set(rc={'figure.figsize':(18,18)})
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45, # rotaciona o eixo y 45o
    horizontalalignment='right' 
);

# %%
# Grava os dados
dfsteam_salvo.to_csv("Steam_2024_bestRevenue_1500_depoislimpeza.csv", index=False)

# %% [markdown]
# ## Normalização - "Min-Max Scaler"

# %%
# Import dos módulos
from sklearn.preprocessing import MinMaxScaler

# %%
# Carregando arquivo csv usando Pandas (método que usaremos neste notebook)
# Leitura do arquivo CSV com separador "," e codificação UTF-8
dfsteam_limpa = pd.read_csv('Steam_2024_bestRevenue_1500_depoislimpeza.csv', sep = ',', encoding = 'UTF-8')

# %%
# Apresenta os dados
dfsteam_limpa.head(3)
# Out:
#               name releaseDate  copiesSold  price     revenue  avgPlaytime  \
# 0  Dark and Darker  07-06-2024     2640903    0.0   8706135.0    31.974027
# 1     Lust Goddess  21-02-2024      456707    0.0   9695496.0    33.544343
# 2    Summoners War  07-01-2024      540801    0.0  10787342.0   112.856340
#
#    reviewScore publisherClass  publishers  developers
# 0           74          Indie    IRONMACE    IRONMACE
# 1           48          Indie  BRAWEA LTD  BRAWEA LTD
# 2            0          Indie      Com2uS      Com2uS

# %%
# Density Plot Univariado
dfsteam_limpa.plot(kind = 'density', subplots = True, layout = (5,5), sharex = False, figsize=(20,20))
plt.show()

# %%
# Obtém os valores X a normalizar
array = dfsteam_limpa.values; X = array[:,2:5] # todos os registros colunas 2 a 5 (exclusivo)

# %%
# Transformando os dados para a mesma escala (entre 0 e 1)
# Gerando a nova escala (normalizando os dados)
scaler = MinMaxScaler(feature_range = (0, 1)) # obtém o objeto que realiza a escala 
rescaledX = scaler.fit_transform(X)  # aplica a escala

# %%
# Identifica o tipo do objeto retornado em rescaledX
type(rescaledX)
# Out:
# numpy.ndarray

# %%
# Sumarizando os dados transformados
print("Dados Originais: \n\n", X)
print("\nDados Normalizados: \n\n", rescaledX)
# Out:
# Dados Originais:
#
#  [[2640903 0.0 8706135.0]
#  [456707 0.0 9695496.0]
#  [540801 0.0 10787342.0]
#  ...
#  [7242 32.0 208569.0]
#  [120703 32.99 3740762.0]
#  [632326 33.32 17732078.0]]
#
# Dados Normalizados:
#
#  [[8.58922304e-02 0.00000000e+00 2.51679304e-01]
#  [1.48347486e-02 0.00000000e+00 2.80348259e-01]
#  [1.75705415e-02 0.00000000e+00 3.11986947e-01]
#  ...
#  [2.12502665e-04 9.60384154e-01 5.44325940e-03]
#  [3.90367917e-03 9.90096038e-01 1.07796478e-01]
#  [2.05480838e-02 1.00000000e+00 5.13226257e-01]]

# %%
# Apresenta o shape do array
array[:,0:2].shape
# Out:
# (1237, 2)

# %%
# Apresenta o shape do rescaledX
rescaledX.shape
# Out:
# (1237, 3)

# %%
# Apresenta o shape do array a partir da 5a posição
array[:,5:].shape
# Out:
# (1237, 5)

# %%
# Retornando os valores para o array concatenando todos em um único arrayAtual
arrayAtual = np.column_stack((array[:,0:2], rescaledX))
arrayAtual = np.column_stack((arrayAtual, array[:,5:]))

# %%
# Array concatenado e seu formato
arrayAtual.shape
# Out:
# (1237, 10)

# %%
# Cria um dataframe a partir do array finalizado
dataframeCriado = pd.DataFrame(arrayAtual)

# %%
# Mostra os 5 primeiros registros
dataframeCriado.head()
# Out:
#                             0           1         2    3         4  \
# 0             Dark and Darker  07-06-2024  0.085892  0.0  0.251679
# 1                Lust Goddess  21-02-2024  0.014835  0.0  0.280348
# 2               Summoners War  07-01-2024  0.017571  0.0  0.311987
# 3  Firestone: Online Idle RPG  01-04-2024  0.010878  0.0  0.454034
# 4       Viking Rise: Valhalla  21-05-2024  0.000645  0.0  0.006919
#
#             5   6      7                        8                        9
# 0   31.974027  74  Indie                 IRONMACE                 IRONMACE
# 1   33.544343  48  Indie               BRAWEA LTD               BRAWEA LTD
# 2   112.85634   0  Indie                   Com2uS                   Com2uS
# 3  296.332852  79  Indie          Holyday Studios          Holyday Studios
# 4   36.620297  75  Indie  IGG SINGAPORE PTE. LTD.  IGG SINGAPORE PTE. LTD.

# %%
# Modifica os nomes das colunas para o nome original
dataframeCriado.columns = dfsteam_limpa.columns

# %%
# Reinserindo os dados normalizados para o dataframe original
dfsteam_limpa = dataframeCriado

# %%
# mostrando os dados do dataframe normalizados
dfsteam_limpa.head()
# Out:
#                          name releaseDate copiesSold price   revenue  \
# 0             Dark and Darker  07-06-2024   0.085892   0.0  0.251679
# 1                Lust Goddess  21-02-2024   0.014835   0.0  0.280348
# 2               Summoners War  07-01-2024   0.017571   0.0  0.311987
# 3  Firestone: Online Idle RPG  01-04-2024   0.010878   0.0  0.454034
# 4       Viking Rise: Valhalla  21-05-2024   0.000645   0.0  0.006919
#
#   avgPlaytime reviewScore publisherClass               publishers  \
# 0   31.974027          74          Indie                 IRONMACE
# 1   33.544343          48          Indie               BRAWEA LTD
# 2   112.85634           0          Indie                   Com2uS
# 3  296.332852          79          Indie          Holyday Studios
# 4   36.620297          75          Indie  IGG SINGAPORE PTE. LTD.
#
#                 developers
# 0                 IRONMACE
# 1               BRAWEA LTD
# 2                   Com2uS
# 3          Holyday Studios
# 4  IGG SINGAPORE PTE. LTD.

# %%
# Density Plot Univariado
dfsteam_limpa.plot(kind = 'density', subplots = True, layout = (5,5), sharex = False, figsize=(20,20))
plt.show()

# %%
# Grava os valores
dfsteam_limpa.to_csv("Steam_2024_bestRevenue_1500_minmax.csv", index=False)

# %% [markdown]
# ## Normalização: Padronização (escore-z)

# %%
# Import dos módulos associados ao escore-z
from sklearn.preprocessing import StandardScaler

# %%
# Carregando arquivo csv usando Pandas (método que usaremos neste notebook)
# Leitura do arquivo CSV com separador "," e codificação UTF-8
dfsteam_normal = pd.read_csv('Steam_2024_bestRevenue_1500_minmax.csv', sep = ',', encoding = 'UTF-8')

# %%
dfsteam_normal.head(3)
# Out:
#               name releaseDate  copiesSold  price   revenue  avgPlaytime  \
# 0  Dark and Darker  07-06-2024    0.085892    0.0  0.251679    31.974027
# 1     Lust Goddess  21-02-2024    0.014835    0.0  0.280348    33.544343
# 2    Summoners War  07-01-2024    0.017571    0.0  0.311987   112.856340
#
#    reviewScore publisherClass  publishers  developers
# 0           74          Indie    IRONMACE    IRONMACE
# 1           48          Indie  BRAWEA LTD  BRAWEA LTD
# 2            0          Indie      Com2uS      Com2uS

# %%
# Apresenta o histograma com a média e o desvio padrão do atributo reviewScore
dfsteam_normal.reviewScore.hist(figsize=(8,8))
print("Média: {}, Desvio Padrão: {}".format(dfsteam_normal.reviewScore.mean(), dfsteam_normal.reviewScore.std()))
# Out:
# Média: 76.86337914308811, Desvio Padrão: 24.011491165473863

# %%
# Apresenta o dataframe normalizado e padronizado
dfsteam_normal.head()
# Out:
#                          name releaseDate  copiesSold  price   revenue  \
# 0             Dark and Darker  07-06-2024    0.085892    0.0  0.251679
# 1                Lust Goddess  21-02-2024    0.014835    0.0  0.280348
# 2               Summoners War  07-01-2024    0.017571    0.0  0.311987
# 3  Firestone: Online Idle RPG  01-04-2024    0.010878    0.0  0.454034
# 4       Viking Rise: Valhalla  21-05-2024    0.000645    0.0  0.006919
#
#    avgPlaytime  reviewScore publisherClass               publishers  \
# 0    31.974027           74          Indie                 IRONMACE
# 1    33.544343           48          Indie               BRAWEA LTD
# 2   112.856340            0          Indie                   Com2uS
# 3   296.332852           79          Indie          Holyday Studios
# 4    36.620297           75          Indie  IGG SINGAPORE PTE. LTD.
#
#                 developers
# 0                 IRONMACE
# 1               BRAWEA LTD
# 2                   Com2uS
# 3          Holyday Studios
# 4  IGG SINGAPORE PTE. LTD.

# %%
# Média depois da padronização
dfsteam_normal.reviewScore.mean()
# Out:
# np.float64(76.86337914308811)

# %%
# Desvio padrão depois da padronização
dfsteam_normal.reviewScore.std()
# Out:
# np.float64(24.011491165473863)

# %%
# apresenta o mapa de calor resultante 
dfsteam_numeric = dfsteam_normal.select_dtypes(include=[float, int])
ax = sns.heatmap(dfsteam_numeric.corr(), vmin=-1, vmax=1, center=0, annot=True, cmap = "PiYG")
sns.set(rc={'figure.figsize':(18,18)})
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45, # rotaciona o eixo y 45o
    horizontalalignment='right' 
);

# %%
# Density Plot Univariado
dfsteam_normal.plot(kind = 'density', subplots = True, layout = (5,5), sharex = False, figsize=(20,20))
plt.show()

# %% [markdown]
# Observe que todos os atributos preditores estão com valores entre -1 e 1.

# %%
# Grava os dados
dfsteam_normal.to_csv("Steam_2024_bestRevenue_1500_escorez.csv", index=False)

# %% [markdown]
# ## One-Hot Encoding: Variáveis categóricas em numéricas

# %%
# Carregando arquivo csv usando Pandas (método que usaremos neste notebook)
# Leitura do arquivo CSV com separador "," e codificação UTF-8
dfsteam_normal = pd.read_csv('Steam_2024_bestRevenue_1500_escorez.csv', sep = ',', encoding = 'UTF-8')

# %%
# mostra o shape (total de registros por colunas)
dfsteam_normal.shape
# Out:
# (1237, 10)

# %%
# Apresenta os quatro primeiros registros
dfsteam_normal.head(4)
# Out:
#                          name releaseDate  copiesSold  price   revenue  \
# 0             Dark and Darker  07-06-2024    0.085892    0.0  0.251679
# 1                Lust Goddess  21-02-2024    0.014835    0.0  0.280348
# 2               Summoners War  07-01-2024    0.017571    0.0  0.311987
# 3  Firestone: Online Idle RPG  01-04-2024    0.010878    0.0  0.454034
#
#    avgPlaytime  reviewScore publisherClass       publishers       developers
# 0    31.974027           74          Indie         IRONMACE         IRONMACE
# 1    33.544343           48          Indie       BRAWEA LTD       BRAWEA LTD
# 2   112.856340            0          Indie           Com2uS           Com2uS
# 3   296.332852           79          Indie  Holyday Studios  Holyday Studios

# %%
# Realiza o agrupamento por publishers
dfsteam_normal.groupby('publisherClass').size()
# Out:
# publisherClass
# Indie    1237
# dtype: int64

# %%
# Identifica o total de publisherss
dfsteam_normal.publisherClass.nunique()
# Out:
# 1

# %%
# converte as variáveis categóricas (mais de dois valores por atributo) para dummies (numéricas)
# Ou seja, aplica o One-Hot Encoding
dfsteam_dummies = pd.get_dummies(dfsteam_normal, columns=['publisherClass'])
dfsteam_dummies
# Out:
#                                          name releaseDate  copiesSold  \
# 0                             Dark and Darker  07-06-2024    0.085892
# 1                                Lust Goddess  21-02-2024    0.014835
# 2                               Summoners War  07-01-2024    0.017571
# 3                  Firestone: Online Idle RPG  01-04-2024    0.010878
# 4                       Viking Rise: Valhalla  21-05-2024    0.000645
# ...                                       ...         ...         ...
# 1232                              New Star GP  07-03-2024    0.000498
# 1233                              Galacticare  23-05-2024    0.000383
# 1234  Nancy Drew®: Mystery of the Seven Keys™  20-06-2024    0.000213
# 1235                         Le Mans Ultimate  20-02-2024    0.003904
# 1236                                  Bodycam  07-06-2024    0.020548
#
#          price   revenue  avgPlaytime  reviewScore                 publishers  \
# 0     0.000000  0.251679    31.974027           74                   IRONMACE
# 1     0.000000  0.280348    33.544343           48                 BRAWEA LTD
# 2     0.000000  0.311987   112.856340            0                     Com2uS
# 3     0.000000  0.454034   296.332852           79            Holyday Studios
# 4     0.000000  0.006919    36.620297           75    IGG SINGAPORE PTE. LTD.
# ...        ...       ...          ...          ...                        ...
# 1232  0.900060  0.007708     8.869371            0  Five Aces Publishing Ltd.
# 1233  0.900060  0.008346    13.665298           91                 CULT Games
# 1234  0.960384  0.005443     7.070747           60            HeR Interactive
# 1235  0.990096  0.107796    24.519898           78                 Studio 397
# 1236  1.000000  0.513226     8.028880           74             Reissad Studio
#
#                    developers  publisherClass_Indie
# 0                    IRONMACE                  True
# 1                  BRAWEA LTD                  True
# 2                      Com2uS                  True
# 3             Holyday Studios                  True
# 4     IGG SINGAPORE PTE. LTD.                  True
# ...                       ...                   ...
# 1232      New Star Games Ltd.                  True
# 1233         Brightrock Games                  True
# 1234          HeR Interactive                  True
# 1235               Studio 397                  True
# 1236           Reissad Studio                  True
#
# [1237 rows x 10 columns]

# %%
# Reorganiza os índices
dfsteam_dummies.reset_index(inplace=True); dfsteam_dummies
# Out:
#       index                                     name releaseDate  copiesSold  \
# 0         0                          Dark and Darker  07-06-2024    0.085892
# 1         1                             Lust Goddess  21-02-2024    0.014835
# 2         2                            Summoners War  07-01-2024    0.017571
# 3         3               Firestone: Online Idle RPG  01-04-2024    0.010878
# 4         4                    Viking Rise: Valhalla  21-05-2024    0.000645
# ...     ...                                      ...         ...         ...
# 1232   1232                              New Star GP  07-03-2024    0.000498
# 1233   1233                              Galacticare  23-05-2024    0.000383
# 1234   1234  Nancy Drew®: Mystery of the Seven Keys™  20-06-2024    0.000213
# 1235   1235                         Le Mans Ultimate  20-02-2024    0.003904
# 1236   1236                                  Bodycam  07-06-2024    0.020548
#
#          price   revenue  avgPlaytime  reviewScore                 publishers  \
# 0     0.000000  0.251679    31.974027           74                   IRONMACE
# 1     0.000000  0.280348    33.544343           48                 BRAWEA LTD
# 2     0.000000  0.311987   112.856340            0                     Com2uS
# 3     0.000000  0.454034   296.332852           79            Holyday Studios
# 4     0.000000  0.006919    36.620297           75    IGG SINGAPORE PTE. LTD.
# ...        ...       ...          ...          ...                        ...
# 1232  0.900060  0.007708     8.869371            0  Five Aces Publishing Ltd.
# 1233  0.900060  0.008346    13.665298           91                 CULT Games
# 1234  0.960384  0.005443     7.070747           60            HeR Interactive
# 1235  0.990096  0.107796    24.519898           78                 Studio 397
# 1236  1.000000  0.513226     8.028880           74             Reissad Studio
#
#                    developers  publisherClass_Indie
# 0                    IRONMACE                  True
# 1                  BRAWEA LTD                  True
# 2                      Com2uS                  True
# 3             Holyday Studios                  True
# 4     IGG SINGAPORE PTE. LTD.                  True
# ...                       ...                   ...
# 1232      New Star Games Ltd.                  True
# 1233         Brightrock Games                  True
# 1234          HeR Interactive                  True
# 1235               Studio 397                  True
# 1236           Reissad Studio                  True
#
# [1237 rows x 11 columns]

# %%
dfsteam_dummies.drop(columns=['index'], inplace=True); dfsteam_dummies
# Out:
#                                          name releaseDate  copiesSold  \
# 0                             Dark and Darker  07-06-2024    0.085892
# 1                                Lust Goddess  21-02-2024    0.014835
# 2                               Summoners War  07-01-2024    0.017571
# 3                  Firestone: Online Idle RPG  01-04-2024    0.010878
# 4                       Viking Rise: Valhalla  21-05-2024    0.000645
# ...                                       ...         ...         ...
# 1232                              New Star GP  07-03-2024    0.000498
# 1233                              Galacticare  23-05-2024    0.000383
# 1234  Nancy Drew®: Mystery of the Seven Keys™  20-06-2024    0.000213
# 1235                         Le Mans Ultimate  20-02-2024    0.003904
# 1236                                  Bodycam  07-06-2024    0.020548
#
#          price   revenue  avgPlaytime  reviewScore                 publishers  \
# 0     0.000000  0.251679    31.974027           74                   IRONMACE
# 1     0.000000  0.280348    33.544343           48                 BRAWEA LTD
# 2     0.000000  0.311987   112.856340            0                     Com2uS
# 3     0.000000  0.454034   296.332852           79            Holyday Studios
# 4     0.000000  0.006919    36.620297           75    IGG SINGAPORE PTE. LTD.
# ...        ...       ...          ...          ...                        ...
# 1232  0.900060  0.007708     8.869371            0  Five Aces Publishing Ltd.
# 1233  0.900060  0.008346    13.665298           91                 CULT Games
# 1234  0.960384  0.005443     7.070747           60            HeR Interactive
# 1235  0.990096  0.107796    24.519898           78                 Studio 397
# 1236  1.000000  0.513226     8.028880           74             Reissad Studio
#
#                    developers  publisherClass_Indie
# 0                    IRONMACE                  True
# 1                  BRAWEA LTD                  True
# 2                      Com2uS                  True
# 3             Holyday Studios                  True
# 4     IGG SINGAPORE PTE. LTD.                  True
# ...                       ...                   ...
# 1232      New Star Games Ltd.                  True
# 1233         Brightrock Games                  True
# 1234          HeR Interactive                  True
# 1235               Studio 397                  True
# 1236           Reissad Studio                  True
#
# [1237 rows x 10 columns]

# %%
# Grava os dados
dfsteam_dummies.to_csv("Steam_2024_bestRevenue_1500_oneHot.csv", index=False)

# %% [markdown]
# # Ordenando o Dataset

# %%
# Carregando arquivo csv usando Pandas (método que usaremos neste notebook) com a Preparação dos dados realizada
# Leitura do arquivo CSV com separador "," e codificação UTF-8
dfsteam_preparados = pd.read_csv('Steam_2024_bestRevenue_1500_oneHot.csv', sep = ',', encoding = 'UTF-8')

# %%
# apresenta os dados
dfsteam_preparados.head(3)
# Out:
#               name releaseDate  copiesSold  price   revenue  avgPlaytime  \
# 0  Dark and Darker  07-06-2024    0.085892    0.0  0.251679    31.974027
# 1     Lust Goddess  21-02-2024    0.014835    0.0  0.280348    33.544343
# 2    Summoners War  07-01-2024    0.017571    0.0  0.311987   112.856340
#
#    reviewScore  publishers  developers  publisherClass_Indie
# 0           74    IRONMACE    IRONMACE                  True
# 1           48  BRAWEA LTD  BRAWEA LTD                  True
# 2            0      Com2uS      Com2uS                  True

# %%
# troca branco por espaço nas colunas spaces with '_'  
dfsteam_preparados.columns = [column.replace(" ", "_") for column in dfsteam_preparados.columns]

# %%
# Obtendo o conjunto de nomes dos atributos e colocando em uma lista
cols =dfsteam_preparados.columns.tolist(); cols
# Out:
# ['name',
#  'releaseDate',
#  'copiesSold',
#  'price',
#  'revenue',
#  'avgPlaytime',
#  'reviewScore',
#  'publishers',
#  'developers',
#  'publisherClass_Indie']

# %%
# Alterando a ordem da lista dos nomes dos atributos para que o preço (atributo alvo) seja o último atributo do conjunto
cols_salvo = cols[0:9] + cols[10:]; 
cols_salvo.append(cols[9]); cols_salvo
# Out:
# ['name',
#  'releaseDate',
#  'copiesSold',
#  'price',
#  'revenue',
#  'avgPlaytime',
#  'reviewScore',
#  'publishers',
#  'developers',
#  'publisherClass_Indie']

# %%
# Obtém o dataset contendo as colunas na ordem correta 
dfsteam_preparados_colunasOk = dfsteam_preparados[cols_salvo]; dfsteam_preparados_colunasOk.head(3)
# Out:
#               name releaseDate  copiesSold  price   revenue  avgPlaytime  \
# 0  Dark and Darker  07-06-2024    0.085892    0.0  0.251679    31.974027
# 1     Lust Goddess  21-02-2024    0.014835    0.0  0.280348    33.544343
# 2    Summoners War  07-01-2024    0.017571    0.0  0.311987   112.856340
#
#    reviewScore  publishers  developers  publisherClass_Indie
# 0           74    IRONMACE    IRONMACE                  True
# 1           48  BRAWEA LTD  BRAWEA LTD                  True
# 2            0      Com2uS      Com2uS                  True

# %%
# Apresenta a forma final
dfsteam_preparados_colunasOk.shape
# Out:
# (1237, 10)

# %%
# Mostra as colunas do dataset
dfsteam_preparados_colunasOk.columns
# Out:
# Index(['name', 'releaseDate', 'copiesSold', 'price', 'revenue', 'avgPlaytime',
#        'reviewScore', 'publishers', 'developers', 'publisherClass_Indie'],
#       dtype='object')

# %%
# Grava os dados
dfsteam_preparados_colunasOk.to_csv("Steam_2024_bestRevenue_1500_preparadosColOk.csv", index=False)
